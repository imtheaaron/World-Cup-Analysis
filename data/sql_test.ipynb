# %%
from flask import Flask, jsonify, render_template
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('sqlite:///C:\\Users\\zulim2\\Downloads\\Analytics\\World-Cup-Analysis\\data\\world_cup_db.db', echo=False)
conn = engine.connect()

Base = automap_base()
Base.prepare(engine, reflect=True)
session = Session(engine)

# %%
engine.execute("SELECT confederation FROM world_cup_db").fetchall()
# Out:
# [('CONMEBOL',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CONMEBOL',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CONMEBOL',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CONMEBOL',),
#  ('UEFA',),
#  ('CONMEBOL',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('UEFA',),
#  ('AFC',),
#  ('UEFA',),
#  ('CONMEBOL',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('CAF',),
#  ('UEFA',),
#  ('UEFA',),
#  ('AFC',),
#  ('CAF',),
#  ('CONMEBOL',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CONMEBOL',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('UEFA',),
#  ('AFC',),
#  ('CAF',),
#  (None,),
#  ('UEFA',),
#  ('AFC',),
#  ('UEFA',),
#  ('CAF',),
#  ('UEFA',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('UEFA',),
#  ('AFC',),
#  ('UEFA',),
#  ('CONCACAF',),
#  ('OFC',),
#  ('CONCACAF',),
#  ('CAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('CONMEBOL',),
#  ('AFC',),
#  ('AFC',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('CONMEBOL',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('AFC',),
#  ('CAF',),
#  ('UEFA',),
#  ('AFC',),
#  ('CAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('AFC',),
#  ('UEFA',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('AFC',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CAF',),
#  ('AFC',),
#  ('UEFA',),
#  ('CAF',),
#  ('CAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('CAF',),
#  ('UEFA',),
#  ('AFC',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('CAF',),
#  ('AFC',),
#  ('UEFA',),
#  ('AFC',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('CAF',),
#  ('AFC',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('CONCACAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('CAF',),
#  ('AFC',),
#  ('OFC',),
#  ('UEFA',),
#  ('AFC',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('CAF',),
#  ('AFC',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('AFC',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('OFC',),
#  ('UEFA',),
#  ('AFC',),
#  ('AFC',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('CAF',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('AFC',),
#  ('OFC',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('CAF',),
#  ('CAF',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('OFC',),
#  ('OFC',),
#  ('OFC',),
#  ('AFC',),
#  ('AFC',),
#  ('AFC',),
#  ('OFC',),
#  ('CONCACAF',),
#  ('OFC',),
#  ('CONCACAF',),
#  ('OFC',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('CAF',),
#  ('AFC',),
#  ('CAF',),
#  ('CAF',),
#  ('OFC',),
#  ('CONCACAF',),
#  ('AFC',),
#  ('UEFA',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('UEFA',),
#  ('CONCACAF',),
#  ('UEFA',),
#  ('CAF',)]
