# %%
import pandas as pd
import csv

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///C:\\Users\\zulim2\\Downloads\\Analytics\\World-Cup-Analysis\\data\\world_cup_db.db', echo=False)

# %%
df = pd.read_csv("World_Cup_Data_Combined.csv")
df.to_sql("world_cup_db", con=engine, if_exists='fail', index=False)

# %%
df
# Out:
#                          Team ABRV  WC_All_Time Confederation     MP     W  \
# 0                     Uruguay  URU          9.0      CONMEBOL   51.0  20.0
# 1                   Argentina  ARG          4.0      CONMEBOL   77.0  42.0
# 2                         USA  USA         23.0      CONCACAF   33.0   8.0
# 3                      Serbia  SRB         12.0          UEFA   43.0  17.0
# 4                       Chile  CHI         20.0      CONMEBOL   33.0  11.0
# 5                      Brazil  BRA          1.0      CONMEBOL  104.0  70.0
# 6                      France  FRA          7.0          UEFA   59.0  28.0
# 7                     Romania  ROU         24.0          UEFA   21.0   8.0
# 8                    Paraguay  PAR         22.0      CONMEBOL   27.0   7.0
# 9                        Peru  PER         37.0      CONMEBOL   15.0   4.0
# 10                    Belgium  BEL         14.0          UEFA   41.0  14.0
# ...

# %%
engine.execute("SELECT * FROM world_cup_db").fetchall()
# Out:
# [('Uruguay', 'URU', 9.0, 'CONMEBOL', 51.0, 20.0, 12.0, 19.0, 80.0, 71.0, 72.0, 1.41, 12.0, 1.0, None, None, 1.0, 4.0, None, 12.0, 7.0, 4.0, 13.0, None, None, 16.0, 16.0, 18.0, None, 38.0, None, 24.0, 26.0, 22.0, None, 16.0, 4.0, 7.0, 12.0, 14.0),
#  ('Argentina', 'ARG', 4.0, 'CONMEBOL', 77.0, 42.0, 14.0, 21.0, 131.0, 84.0, 140.0, 1.82, 16.0, 2.0, 9.0, None, None, None, 13.0, 10.0, 5.0, None, 8.0, 1.0, 11.0, 1.0, 2.0, 8.0, 10.0, 6.0, 6.0, 3.0, 18.0, 9.0, 6.0, 7.0, 5.0, 5.0, 2.0, 5.0),
#  ('USA', 'USA', 23.0, 'CONCACAF', 33.0, 8.0, 6.0, 19.0, 37.0, 62.0, 30.0, 0.91, 10.0, 3.0, 16.0, None, 10.0, None, None, None, None, None, None, None, None, None, 23.0, 23.0, 14.0, 11.0, 32.0, 13.0, 8.0, 5.0, 25.0, 14.0, 12.0, 13.0, 15.0, 25.0),
#  ('Serbia', 'SRB', 12.0, 'UEFA', 43.0, 17.0, 8.0, 18.0, 64.0, 59.0, 59.0, 1.37, 11.0, 4.0, None, None, 5.0, 7.0, 5.0, 4.0, None, None, 7.0, None, 16.0, None, 5.0, 78.0, None, 8.0, 10.0, 10.0, None, 44.0, 32.0, 15.0, 23.0, 30.0, None, 34.0),
# ...
